# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")
data.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY

# %%
data.shape
# Out:
# (20640, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data['ocean_proximity'].nunique()
# Out:
# 5

# %%
data['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
data['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
data.hist(bins=25, figsize=(15,15))
plt.show()

# %%
data.hist(bins=50, figsize=(15,15))
plt.show()

# %%
data.hist(figsize=(15,15))
plt.show()

# %%
data["median_income"].hist()
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
# 
sns.scatterplot(x="median_house_value", y = "total_bedrooms", hue= "ocean_proximity", data = data, alpha=0.2)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='total_bedrooms'>

# %%
sns.scatterplot(x="median_house_value", y = "total_bedrooms", hue= "households", data = data, alpha=0.4)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='total_bedrooms'>

# %%
sns.scatterplot(x="median_house_value", y = "total_bedrooms", hue= "median_income", data = data, alpha=0.3)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='total_bedrooms'>

# %% [markdown]
# The median income is in a kind of inverse relationship with total bedrooms area, and positive correlation with median house values

# %%
sns.scatterplot(x="median_house_value", y = "total_bedrooms", hue= "total_rooms", data = data, alpha=0.3)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='total_bedrooms'>

# %%
sns.scatterplot(x="median_house_value", y = "total_bedrooms", hue= "housing_median_age", data = data, alpha=0.3)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='total_bedrooms'>

# %%
sns.scatterplot(x="median_house_value", y = "housing_median_age", hue= "ocean_proximity", data = data, alpha=0.1)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='housing_median_age'>

# %%
sns.scatterplot(x="total_bedrooms", y = "housing_median_age", hue= "ocean_proximity", data = data, alpha=0.1)
# Out:
# <AxesSubplot:xlabel='total_bedrooms', ylabel='housing_median_age'>

# %%
sns.scatterplot(x="median_house_value", y = "total_bedrooms", hue= "longitude", data = data, alpha=0.3)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='total_bedrooms'>

# %%
sns.scatterplot(x="median_house_value", y = "longitude", hue= "total_bedrooms", data = data, alpha=0.3)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='longitude'>

# %%
sns.scatterplot(x="longitude", y = "total_bedrooms", hue= "ocean_proximity", data = data, alpha=0.3)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='total_bedrooms'>

# %%
sns.scatterplot(x="longitude", y = "latitude", hue= "ocean_proximity", data = data, alpha=0.3)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
sns.scatterplot(x="longitude", y = "latitude", hue= "median_house_value", data = data, alpha=0.3)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
sns.scatterplot(x="longitude", y = "latitude", hue= "total_bedrooms", data = data, alpha=0.5)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
sns.scatterplot(x="longitude", y = "latitude", hue= "total_rooms", data = data, alpha=0.5)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
sns.scatterplot(x="longitude", y = "total_bedrooms", hue= "median_house_value", data = data, alpha=0.3)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='total_bedrooms'>

# %% [markdown]
# most of high median house values are located between -117 and -121 longitude coordinates

# %%
sns.scatterplot(x="median_house_value", y = "latitude", hue= "total_bedrooms", data = data, alpha=0.3)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='latitude'>

# %%
sns.scatterplot(x="latitude", y = "total_bedrooms", hue= "median_house_value", data = data, alpha=0.3)
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='total_bedrooms'>

# %%
data["bedrooms_per_house"] = data["total_bedrooms"]/data["total_rooms"]

# %%
data["population_per_household"]=data["population"]/data["households"]

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# All the plots tells that there are no direct correlations to the total bed rooms area so replacing it with median would be accepable option.

# %%
 data["total_bedrooms"] = data['total_bedrooms'].transform(lambda x: x.fillna(x.median()))

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.shape
# Out:
# (20640, 10)

# %% [markdown]
# train,test,val = data[:18640],data[18640:19640],data[19640:]
# len(train), len(test), len(val)

# %%
#x_train,y_train = train.to_numpy()[data.drop(columns=["median_house_value"]),data["median_house_value"]]

# %%
housing = data.drop("median_house_value", axis=1) # drop labels for training set
housing_labels = data["median_house_value"]

# %%
#limit income

# %% [markdown]
# data["income_category"]= np.ceil(data['median_income']/1.5)
# #put values above 5th into 5th
# data["income_category"].where(data['income_category']< 5,other=5.0, inplace = True )

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.plot(kind="scatter", x = "longitude" , y = "latitude", alpha = 0.2)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
data.plot(kind="scatter", x = "longitude" , y = "latitude", alpha = 0.2, s= data["population"]/100 , label= "population", c = "median_house_value", cmap=plt.get_cmap("jet"))
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
#data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
# income_category     -0.010690 -0.085528           -0.146920     0.220528
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# ...

# %%
corr = data.corr()
corr["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# income_category       0.643892
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049686
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# Name: median_house_value, dtype: float64

# %%
housing = data.dropna(subset=["total_bedrooms"])

# %% [markdown]
# ### Splitting data

# %%
X = data.drop("median_house_value", axis=1)
y = data["median_house_value"]

# %%
 X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size =0.2, random_state=5) #, stratify = df['']
